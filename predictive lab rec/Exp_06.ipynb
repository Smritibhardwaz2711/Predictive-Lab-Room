# %%
import pandas as pd
iris = pd.read_csv("D:\\data sets\\IRIS (1).csv")   # Load dataset
print(iris)

import numpy as np
x = iris[['SepalLengthCm', 'SepalWidthCm']]         # Independent variables
y = iris.PetalLengthCm                              # Dependent variable

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)  # Split data

from sklearn.linear_model import LinearRegression
LR = LinearRegression()
training = LR.fit(x_train, y_train)                 # Train model
y_pred = LR.predict(x_test)                         # Predict on test data
print(y_pred)                                       # Print predictions
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB 187.9 kB/s eta 0:01:01
#    ---------------------------------------- 0.0/11.3 MB 196.9 kB/s eta 0:00:58
#    ---------------------------------------- 0.1/11.3 MB 280.5 kB/s eta 0:00:41
#    ---------------------------------------- 0.1/11.3 MB 309.1 kB/s eta 0:00:37
#    ---------------------------------------- 0.1/11.3 MB 361.0 kB/s eta 0:00:32
#     --------------------------------------- 0.1/11.3 MB 387.0 kB/s eta 0:00:29
#     --------------------------------------- 0.2/11.3 MB 403.5 kB/s eta 0:00:28
#     --------------------------------------- 0.2/11.3 MB 403.5 kB/s eta 0:00:28
# ...
